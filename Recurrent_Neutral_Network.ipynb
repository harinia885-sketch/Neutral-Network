# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import LSTM

# %%
mnist=keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train/255.0,x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.layers import Input,Dense
from tensorflow.keras.models import Model
input_shape=(28,28)
inputs=Input(shape=input_shape)
rnn_layer=LSTM(128)(inputs)
outputs=Dense(10,activation='softmax')(rnn_layer)
model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,validation_split=0.1,epochs=5)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 66s 38ms/step - accuracy: 0.8789 - loss: 0.3742 - val_accuracy: 0.9695 - val_loss: 0.1132
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 64s 38ms/step - accuracy: 0.9661 - loss: 0.1138 - val_accuracy: 0.9733 - val_loss: 0.0925
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 65s 38ms/step - accuracy: 0.9766 - loss: 0.0765 - val_accuracy: 0.9785 - val_loss: 0.0745
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 65s 38ms/step - accuracy: 0.9814 - loss: 0.0606 - val_accuracy: 0.9853 - val_loss: 0.0486
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 81s 38ms/step - accuracy: 0.9852 - loss: 0.0491 - val_accuracy: 0.9847 - val_loss: 0.0569
