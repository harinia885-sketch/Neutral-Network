# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
mnist=keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train/255.0,x_test/255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[50000])

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
model=keras.Sequential([
    layers.Flatten(input_shape=(28,28,1)),
    layers.Dense(128,activation='relu'),
    layers.Dense(10,activation='softmax')]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,validation_split=0.1,epochs=5)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9216 - loss: 0.2716 - val_accuracy: 0.9658 - val_loss: 0.1209
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9641 - loss: 0.1227 - val_accuracy: 0.9740 - val_loss: 0.0960
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9752 - loss: 0.0841 - val_accuracy: 0.9740 - val_loss: 0.0838
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9805 - loss: 0.0636 - val_accuracy: 0.9740 - val_loss: 0.0857
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9847 - loss: 0.0493 - val_accuracy: 0.9795 - val_loss: 0.0719

# %%
y_pred=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred[5980]
# Out:
# array([9.9980545e-01, 2.5032906e-08, 8.5076169e-07, 3.9166343e-07,
#        3.1349707e-08, 1.4612445e-04, 4.9459486e-06, 1.1799294e-06,
#        9.6473869e-08, 4.0943509e-05], dtype=float32)

# %%
import numpy as np
y_prd=np.argmax(y_pred,axis=1)
t=y_prd[5980]
print(t)
# Out:
# 0

# %%
plt.imshow(x_test[456])
tr=y_test[456]
pr=np.argmax(np.argmax(y_pred[456]))
plt.title(f"y_test:{tr},y_pred:{pr}")
# Out:
# Text(0.5, 1.0, 'y_test:2,y_pred:0')

# %%
from google.colab import drive
drive.mount('/content/drive')

model.save('/content/drive/MyDrive/mnist_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model=model.sequential()
model.add(layers.Con)
